# %% [markdown]
# <a href="https://colab.research.google.com/github/ikeyareinaldosae/ITC501---Artificial-Intelligence-Applications/blob/main/Milestone%203%20%26%20Portfolio%20Brief%3A%20Deploying%20and%20Monitoring%20AI%20Applications/Milestone_3_%26_Portfolio_Brief_Deploying_and_Monitoring_AI_Applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install fastapi uvicorn[standard] scikit-learn joblib jinja2 pandas python-multipart

# %%
# !mkdir app

# !touch app/main.py

# %%
import tensorflow as tf
from google.colab import drive
drive.mount('/content/drive')

model_path = '/content/drive/MyDrive/models/cifar10_model.keras'

model = tf.keras.models.load_model(model_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install --upgrade gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 54.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 2.5.0
#     Uninstalling gradio_client-2.5.0:
#       Successfully uninstalled gradio_client-2.5.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 6.20.0
#     Uninstalling gradio-6.20.0:
#       Successfully uninstalled gradio-6.20.0
# ...

# %%
# !uvicorn app.main:app --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [14667] using WatchFiles
# 2026-08-15 02:58:16.213842: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# INFO:     Started server process [14669]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [14669]
# INFO:     Stopping reloader process [14667]

# %%
# !python gradio_app.py
# Out:
# 2026-08-15 02:59:03.071941: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://5a2186d426609ec888.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Traceback (most recent call last):
# ...
